# %%
print('hellow github')
# Out:
# hellow github

# %% [markdown]
# ---
# title: "My Report"
# format: html
# ---

# %%
## Introduction

# Here is a sine wave:


import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title("Nice Sine Wave")
plt.show()
