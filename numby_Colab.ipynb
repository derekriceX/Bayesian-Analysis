# %% [markdown]
# <a href="https://colab.research.google.com/github/derekriceX/Bayesian-Analysis/blob/main/numby_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

a = np.array([1,2,3])

print(a)
# Out:
# [1 2 3]
